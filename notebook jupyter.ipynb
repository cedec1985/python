# %%
a=2
b=3
print(a+b)
# Out:
# 5

# %%
def ma_fonction(x,y):
    return x+y

# %%
ma_fonction(2,10)
# Out:
# 12

# %%
import numpy as np
import matplotlib.pyplot as plt
temps=[1,2,3,4,5,6,7,9]
concentration=[5.5,7.2,11.8,13.6,19.1,21.7,29.4,32.5]
plt.scatter(temps,concentration,marker ='*',color ='blue')
plt.xlabel('temps (h)')
plt.ylabel('concentration(mg/ml)')
plt.title('concentration de produit en fonction du temps')
x=np.linspace( min(temps), max(temps), 50)
y=2 + 3*x
plt.plot(x, y, color='green')
plt.show()
